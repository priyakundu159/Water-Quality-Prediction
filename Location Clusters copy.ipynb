# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
# Read the dataset
data = pd.read_csv('/Users/priyakundu/Documents/NYU Capstone WaterVue Files/Data Processing/Updated_Dataframe_WaterQual.csv')
data
# Out:
#                           Location Sample Date  Chlorophyll A  \
# 0          #1 HILLSBORO CANAL US 1  2006-02-28      12.100000
# 1          #1 HILLSBORO CANAL US 1  2006-08-31       4.430000
# 2          #1 HILLSBORO CANAL US 1  2007-02-28       2.605000
# 3          #1 HILLSBORO CANAL US 1  2007-08-31       4.890000
# 4          #1 HILLSBORO CANAL US 1  2008-02-29       5.925000
# ..                             ...         ...            ...
# 853  #89 NOB HILL RD POMPANO CANAL  2020-02-29       3.933333
# 854  #89 NOB HILL RD POMPANO CANAL  2020-08-31       1.570000
# 855  #89 NOB HILL RD POMPANO CANAL  2021-02-28       2.966667
# 856  #89 NOB HILL RD POMPANO CANAL  2021-08-31       5.510000
# 857  #89 NOB HILL RD POMPANO CANAL  2022-02-28       2.900000
#
#      Dissolved Oxygen   Salinity  Specific Conductance  Total Nitrogen  \
# 0            6.980000  19.400000             10.351373        0.830000
# 1            5.540000  15.750000             10.165844        0.981000
# ...

# %%
# Select the numerical columns for clustering
X = data.iloc[:, 2:].values

# Normalize the data
scaler = StandardScaler()
data_normalized = scaler.fit_transform(X)

# Define the number of clusters
num_clusters = 2

# Perform KMeans clustering
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
clusters = kmeans.fit_predict(data_normalized)

# Assign cluster labels to locations
location_clusters = {}
for location, cluster in zip(data["Location"].unique(), clusters):  # Assuming you have a list of locations
    if cluster not in location_clusters:
        location_clusters[cluster] = [location]
    else:
        location_clusters[cluster].append(location)

# Print out the locations in each cluster
for cluster, locations in location_clusters.items():
    print(f"Cluster {cluster + 1}:")
    print(locations)

# Analyze the cluster centroids and parameter ranges
cluster_centers = scaler.inverse_transform(kmeans.cluster_centers_)
for i, center in enumerate(cluster_centers):
    print(f"\nCluster {i + 1} Centroid (parameter means):")
    print(center)

    # Find minimum and maximum values for each parameter in the cluster
    cluster_data = data[clusters == i]  # Get data points belonging to this cluster
    parameter_mins = np.min(cluster_data, axis=0)
    parameter_maxs = np.max(cluster_data, axis=0)

    print(f"Min values for parameters:")
    print(parameter_mins)
    print(f"Max values for parameters:")
    print(parameter_maxs)
# Out:
# Cluster 1:
# ['#1 HILLSBORO CANAL US 1', '#10 MIDDLE RIVER E SUNRISE', '#110 POMPANO CANAL AT DIXIE AN', '#111 S. FORK MID R. @ N.E. 15', '#12 MIDDLE RIVER NW 31ST AVE', '#15 NEW RIVER ANDREWS AVE', '#17 PLANTATION CANAL @ S-33', '#19 NEW RIVER RIVER REACH', '#22 N NEW RIVER SW 125 AVE', '#24 DANIA CUT-OFF US-1', '#25 HOLLYWOOD CANAL STIRLING', '#28 S NEW RIVER CANAL FLAMINGO', '#31 SNAKE CRK CANAL FLAMINGO', '#32 C-9 CANAL US 27', '#36 ICW COMMERCIAL BLVD', '#38 ICW 17TH ST CAUSEWAY', '#39 ICW MARKER 35', '#4 HILLSBORO CANAL SE GROWERS', '#40 ICW SHERIDAN ST']
# Cluster 2:
# ['#37 ICW SUNRISE BLVD', '#41 ICW HALLANDALE BCH BLVD', '#5 POMPANO CANAL US1', '#6 CYPRESS CREEK DIXIE HWY', '#7 CYPRESS CREEK S. PALM AIRE', '#8 POMPANO CANAL US 441', '#89 NOB HILL RD POMPANO CANAL']
#
# Cluster 1 Centroid (parameter means):
# [ 3.2028286   5.6295471  24.09368076 10.45650817  0.61688019  0.06003072
#   1.31588366]
# Min values for parameters:
# Location                #1 HILLSBORO CANAL US 1
# ...
